# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Анастасия :)
#
# Спасибо за работу на проекте
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны замечательно, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Анастасия :) Вышли на финишную прямую
#
# Критические ❌ комментарии
#
# + сменить тип данных, поменять float на int
# + завершить фильтрацию редких значений в п. 2.4
#
#
# добавил подсказки в бонусную часть, примеры фильтрации
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Анастасия :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии
#
# + отформатировать неявные дубликаты
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы в п.4.1
# + поправить итоговый вывод
#
# добавил подсказки и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Анастасия :) Спасибо, что прислала задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
display(data.head(20))
data.info()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Пропущенные значения

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В датасете 14 столбцов с пропусками. Пропуски в столбцах balcony, parks_around3000, ponds_around3000 могут означать, что в квартире отсутствуют балконы, а поблизости нет парков или водоемов. Поэтому заменим их на 0.
# Пропуски в locality_name сразу заменим на "Unknown", а is_apartment на 'False'

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На самом графике не подписано, что и где изображено. Нужно добавить подписи на оси и описательное название графика

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# За поворот текста отвечает параметр rot
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['balcony'] = data['balcony'].fillna(0)
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
data['locality_name'] = data['locality_name'].fillna('Unknown')
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name               0
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000            0
# parks_nearest           15620
# ponds_around3000            0
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В столбцах airports_nearest, parks_nearest и ponds_nearest может не быть данных, если аэропортов, парков и водоемов рядом нет или расстояние до них неизвестно.
# Природа пропусков days_exposition неизвестна - возможно пропуск появлялся, если объявление появилось и сразу было снято.
# В остальных столбцах данные могут быть пропущены из-за отсутсвия у хозяина точных данных или нежелания заполнять информацию.

# %% [markdown]
# #### Типы данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# Столбец first_day_exposition отображает дату и время публикации

# %%
data['first_day_exposition']
# Out:
# 0        2019-03-07T00:00:00
# 1        2018-12-04T00:00:00
# 2        2015-08-20T00:00:00
# 3        2015-07-24T00:00:00
# 4        2018-06-19T00:00:00
#                 ...
# 23694    2017-03-21T00:00:00
# 23695    2018-01-15T00:00:00
# 23696    2018-02-11T00:00:00
# 23697    2017-03-28T00:00:00
# 23698    2017-07-21T00:00:00
# Name: first_day_exposition, Length: 23699, dtype: object

# %% [markdown]
# Так как время не указано, оставляем только дату в формате date time

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')
data['first_day_exposition']
# Out:
# 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23699, dtype: datetime64[ns]

# %% [markdown]
# Столбцы balcony, parks_around3000 и ponds_around3000 заменим на int

# %%
data['balcony'] = data['balcony'].astype(int)
data['parks_around3000'] = data['parks_around3000'].astype(int)
data['ponds_around3000'] = data['ponds_around3000'].astype(int)

# %% [markdown]
# #### Дубликаты

# %% [markdown]
# Проверим есть ли неявные в столбце с названием местности.

# %%
display(data['locality_name'].unique())
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса
#
# __Оптимальнее поиск дубликатов выполнять после обработки неявных дубликатов__

# %% [markdown]
# В глаза бросается разное написание слова "посёлок". Приведем его к одному виду и заменим "поселок" и "посёлок городского типа" на "посёлок"

# %%
data['locality_name'] = data['locality_name'].str.replace('поселок', 'посёлок', regex = False)
data['locality_name'] = data['locality_name'].str.replace('посёлок городского типа', 'посёлок', 
                                                          regex = False)
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'посёлок Красный Бор', 'Гатчина', 'деревня Фёдоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'посёлок Металлострой', 'посёлок Лебяжье', 'посёлок Сиверский',
#        'посёлок Молодцово', 'посёлок Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'посёлок Ефимовский', 'посёлок Плодовое', 'деревня Заклинье',
#        'посёлок Торковичи', 'посёлок Первомайское', 'Красное Село',
#        'посёлок Понтонный', 'Сясьстрой', 'деревня Старая',
#        'деревня Лесколово', 'посёлок Новый Свет', 'Сланцы',
# ...

# %%
# check
data.locality_name.nunique()
# Out:
# 330

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# код не сохраняет изменения
#
#         data['locality_name'].str.replace('посёлок','поселок')
#         data['locality_name'].str.replace('посёлок городского типа','посёлок')

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# мы потеряли все наименования в состав которых входит слово поселок, например
#
#         'поселок Молодцово',

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.replace.html

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# Теперь проверим есть ли явные дубликаты

# %%
display(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #### Выбивающиеся значения
#
# Сначала посмотрим на значения площадей квартир и высоту потолков

# %%
display(data['total_area'].describe())
display(data['ceiling_height'].describe())
display(data['living_area'].describe())
display(data['kitchen_area'].describe())
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Во всех столбцах есть выбивающиеся значения. Так как природа выбросов не ясна, пока заменим только значения в столбце ceiling_height, где могли быть перепутаны размерности.

# %%
data['ceiling_height'].hist(range = (9, 20))
data[data['ceiling_height'] > 20.0].sort_values('ceiling_height', ascending = True)
data.loc[data['ceiling_height'] >= 20.0, 'ceiling_height'] /= 10
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.729608
# std          0.319850
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23291 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23291 non-null  int64
#  1   last_price            23291 non-null  float64
#  2   total_area            23291 non-null  float64
#  3   first_day_exposition  23291 non-null  datetime64[ns]
#  4   rooms                 23291 non-null  int64
#  5   ceiling_height        14286 non-null  float64
#  6   floors_total          23291 non-null  int64
#  7   living_area           21466 non-null  float64
#  8   floor                 23291 non-null  int64
#  9   is_apartment          23291 non-null  bool
#  10  studio                23291 non-null  bool
#  11  open_plan             23291 non-null  bool
#  12  kitchen_area          21125 non-null  float64
#  13  balcony               23291 non-null  int64
#  14  locality_name         23291 non-null  object
# ...

# %% [markdown]
#  Избавимся от пропущенных значений в колонке по колонке floors_total

# %%
data = data.dropna(subset = ['floors_total'])
#data.info()
data['floors_total'] = data['floors_total'].astype('int')
data['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#
#          6   floors_total                     23613 non-null  float64
#
# пропуски можно удалить, кол-во их минимально

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_faf90_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_faf90_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_faf90_row0_col0" class="data row0 col0" >23,613.00</td>
#                         <td id="T_faf90_row0_col1" class="data row0 col1" >23,613.00</td>
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При оптимальной очистке датасета и сохранении всех пропусков размер окончательной выборки может составить 22500 записей, т.е. реально уложиться в 5%

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_0acde_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0acde_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_0acde_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_0acde_row0_col1" class="data row0 col1" >20.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# #### check nan

# %%
# check.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  float64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  datetime64[ns]
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        14495 non-null  float64
#  6   floors_total          23613 non-null  int64
#  7   living_area           21743 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  bool
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          21382 non-null  float64
#  13  balcony               23613 non-null  int64
#  14  locality_name         23613 non-null  object
# ...

# %%
data.query('floors_total == 60')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 2253            12   3800000.0        45.5           2018-06-28      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2253            2.88            60         27.4      4         False  ...
#
#       kitchen_area  balcony  locality_name  airports_nearest  \
# 2253           7.4        0      Кронштадт           67763.0
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 2253             49488.0                 2          342.0                 3
#
#       ponds_nearest  days_exposition
# 2253          614.0            166.0
#
# [1 rows x 22 columns]

# %%
filter_outliers = data[((data['rooms'] > 8) | (data['total_area'] < 20) 
                | (data['total_area'] > 250)
                | (data['ceiling_height'] < 2.28)
                | (data['ceiling_height'] > 4.70)
                | (data['days_exposition'] < 3)
                | (data['days_exposition'] > 1370)
                | (data['last_price'] < 561672)
                | (data['last_price'] > 124826112)
                | (data['living_area'] < 10)
                | (data['living_area'] > 219)
                | (data['kitchen_area'] < 3.80)
                | (data['kitchen_area'] > 60)
                | (data['floor'] > 26)
                | (data['floors_total'] > 35))]

# %%
data.drop(filter_outliers.index, 
          inplace = True)

# %%
data['ceiling_height'].isna().sum()
# Out:
# 9005

# %%
data.query('ceiling_height < 2.28')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23291 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23291 non-null  int64
#  1   last_price            23291 non-null  float64
#  2   total_area            23291 non-null  float64
#  3   first_day_exposition  23291 non-null  datetime64[ns]
#  4   rooms                 23291 non-null  int64
#  5   ceiling_height        14286 non-null  float64
#  6   floors_total          23291 non-null  int64
#  7   living_area           21466 non-null  float64
#  8   floor                 23291 non-null  int64
#  9   is_apartment          23291 non-null  bool
#  10  studio                23291 non-null  bool
#  11  open_plan             23291 non-null  bool
#  12  kitchen_area          21125 non-null  float64
#  13  balcony               23291 non-null  int64
#  14  locality_name         23291 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит посмотреть в каком населенном пункте находится здание в 60 этажей ... и может ли оно там быть

# %%
# check
data.shape[0]
# Out:
# 23291

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сами значения для фильтрации подобраны корректно, стоит настроить удаление в колонках с пропусками
#
#                          & (data['living_area'] <= 219)
#                         & (data['ceiling_height'] >= 2.28)
#                         & (data['ceiling_height'] <= 4.70)
#                        & (data['days_exposition'] >= 3)
#                        & (data['days_exposition'] <= 1370)
#
#                        & (data['living_area'] >= 10)
#                        & (data['living_area'] <= 219)
#                        & (data['kitchen_area'] >= 3.80)
#                        & (data['kitchen_area'] <= 60)]
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 13 000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделала по-другому, чтобы не добавлять в каждое условие  isna(). Все nan теперь на месте.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />отлично

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
 

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_78966_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_78966_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_78966_row0_col0" class="data row0 col0" >23,291.00</td>
#                         <td id="T_78966_row0_col1" class="data row0 col1" >23,291.00</td>
# ...

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#          'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру за 12 тыс. руб. ..., а на гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим новые столбцы с расчетами

# %%
data['sqr_meter_price'] = data['last_price'] / data['total_area']
data['publication_weekday'] = data['first_day_exposition'].dt.weekday
data['publication_month'] = data['first_day_exposition'].dt.month
data['publication_year'] = data['first_day_exposition'].dt.year

# %%
def floor_category(data):
    if data['floor'] == 1:
        return 'первый'
    elif data['floor'] == data['floors_total']:
        return 'последний'
    elif data['floor'] > 0:
        return 'другой'
    else:
        return np.nan

# %%
data['floor_category'] = data.apply(floor_category, axis = 1)
data['floor_category']
# Out:
# 0        другой
# 1        первый
# 2        другой
# 3        другой
# 4        другой
#           ...
# 23694    другой
# 23695    другой
# 23696    первый
# 23697    другой
# 23698    первый
# Name: floor_category, Length: 23291, dtype: object

# %%
data['floor_category'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит делить код с функцией и остальным кодом, чтобы была возможность для отладки функции

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %%
data['cityCenters_km'] = (data['cityCenters_nearest'] / 1000).round().convert_dtypes();
data['cityCenters_km']
# Out:
# 0          16
# 1          19
# 2          14
# 3           7
# 4           8
#          ...
# 23694       4
# 23695    <NA>
# 23696    <NA>
# 23697      10
# 23698    <NA>
# Name: cityCenters_km, Length: 23291, dtype: Int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Описание данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %%
display(data['total_area'].describe())
ax_total_area = data.plot(y = 'total_area', kind = 'hist', grid = True, bins = 20, figsize = (15,3));
ax_total_area.set_xlabel('Общая площадь')
ax_total_area.set_ylabel('Частота');
# Out:
# count    23291.000000
# mean        58.875314
# std         28.367749
# min         20.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.000000
# max        250.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Основная масса значений располагается в промежутке от 40 до 69м<sup>2</sup> и имеет ненормальное распределение со средним 58.9м<sup>2</sup> и медианой 52м<sup>2</sup>.

# %%
display(data['living_area'].describe())
ax_living_area = data.plot(y = 'living_area', kind = 'hist', grid = True, 
                           bins = 20, figsize = (15,3));
ax_living_area.set_xlabel('Жилая площадь')
ax_living_area.set_ylabel('Частота');
# Out:
# count    21466.00000
# mean        33.72662
# std         18.64538
# min         10.00000
# 25%         18.60000
# 50%         30.00000
# 75%         42.10000
# max        200.00000
# Name: living_area, dtype: float64

# %% [markdown]
# У жилой площади также ненормальное распределение: размах от 18.6 до 42.1м<sup>2</sup> со средним 33.7м<sup>2</sup> и медианой 30м<sup>2</sup>.

# %%
display(data['kitchen_area'].describe())
ax_kitchen_area = data.plot(y = 'kitchen_area', kind = 'hist', grid = True, bins = 20, 
                            figsize = (15,3));
ax_kitchen_area.set_xlabel('Площадь кухни')
ax_kitchen_area.set_ylabel('Частота');
# Out:
# count    21125.000000
# mean        10.399573
# std          5.225838
# min          3.800000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max         60.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Межквартильный размах от 7 до 12м<sup>2</sup>, среднее - 10.4м<sup>2</sup>, а медиана - 9м<sup>2</sup>.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить кол-во корзин к параметрам гистограммы и изменить размер у графиков (увеличить ширину)
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %%
data['last_price'].describe()
# Out:
# count    2.329100e+04
# mean     6.088950e+06
# std      5.762464e+06
# min      5.650000e+05
# 25%      3.414000e+06
# 50%      4.600000e+06
# 75%      6.700000e+06
# max      1.243500e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Чтобы статистика и графики отображились не в экспонинциальной записи, укажим цены в тысячах.

# %%
data['last_price_thousands'] = data['last_price'] / 1000
display(data['last_price_thousands'].describe())
ax_last_price_thousands = data.plot(y = 'last_price_thousands', kind = 'hist', grid = True, 
          bins = 100, figsize = (15,3), range = (0, 100000));
ax_last_price_thousands.set_xlabel('Последняя цена (в тысячах)')
ax_last_price_thousands.set_ylabel('Частота');
# Out:
# count     23291.000000
# mean       6088.949992
# std        5762.463571
# min         565.000000
# 25%        3414.000000
# 50%        4600.000000
# 75%        6700.000000
# max      124350.000000
# Name: last_price_thousands, dtype: float64

# %% [markdown]
# В основном стоимость квартир варьируется от 3414000 до 6700000 рублей со средним в 6088596 и медианой 4600000 рублей. Есть очень высокие значения, которые сильно выбиваются из графика, поэтому мы ограничили график до 100000000, чтобы посмотреть общий тренд.

# %%
display(data['rooms'].describe())
ax_rooms = data.plot(y = 'rooms', kind = 'hist', grid = True, bins = 25, figsize = (15,3));
ax_rooms.set_xlabel('Количество комнат')
ax_rooms.set_ylabel('Частота');
# Out:
# count    23291.000000
# mean         2.051393
# std          1.016174
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          8.000000
# Name: rooms, dtype: float64

# %% [markdown]
# В основном комнат в квартирах от 1 до 3. Среднее и медиана совпадают - 2 комнаты.

# %%
display(data['ceiling_height'].describe())
ax_ceiling_height = data.plot(y = 'ceiling_height', kind = 'hist', 
                              grid = True, bins = 40, figsize = (15,3));
ax_ceiling_height.set_xlabel('Высота потолков (в метрах)')
ax_ceiling_height.set_ylabel('Частота');
# Out:
# count    14286.000000
# mean         2.721058
# std          0.262883
# min          2.300000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max          4.700000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Ранее мы переводили некоторые значения в метры, статистики не особо изменились - большинство наблюдений лежит в промежутке от 2.5 до 2.8м. Медиана и среднее одинаковы - 2.7м.

# %%
display(data['floor'].describe())
ax_floor = data.plot(y = 'floor', kind = 'hist', grid = True, bins = 100, figsize = (15,3));
ax_floor.set_xlabel('Этаж')
ax_floor.set_ylabel('Частота');
# Out:
# count    23291.000000
# mean         5.872483
# std          4.843437
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         26.000000
# Name: floor, dtype: float64

# %% [markdown]
# Здесь мы видим распределение Пуассона с медианой 4 этажа и средним 6 этажей. Минимум - 1 этаж, максимум - 26 этаж.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />          Стоит добавить больше корзин
#
#         ax_floor = data.plot(y = 'floor', kind = 'hist', grid = True, bins = 30, figsize = (15,3));
#
#     Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />можно больше

# %%
# check
display(data['floor'].describe())
ax_floor = data.plot(y = 'floor', kind = 'hist', grid = True, bins = 140, figsize = (15,3));
ax_floor.set_xlabel('Этаж')
ax_floor.set_ylabel('Частота');
# Out:
# count    23291.000000
# mean         5.872483
# std          4.843437
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         26.000000
# Name: floor, dtype: float64

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ...

# %%
display(data['floor_category'].value_counts())
ax_floor_category = data['floor_category'].value_counts().plot(kind='bar');
ax_floor_category.set_xlabel('Тип этажа')
ax_floor_category.set_ylabel('Частота');
# Out:
# другой       17176
# последний     3251
# первый        2864
# Name: floor_category, dtype: int64

# %% [markdown]
# Для категориальной переменной "тип этажа" построим столбчатую диаграмму. Закономерно в категории "другой" находится больше всего наблюдений. Первый и последний этажи встречаются почти одинаково часто.

# %%
display(data['floors_total'].describe())
ax_floors_total = data.plot(y = 'floors_total', kind = 'hist', grid = True, 
                            bins = 50, figsize = (15,3), range = (0, 30));
ax_floors_total.set_xlabel('Общее количество этажей в здании')
ax_floors_total.set_ylabel('Частота');
# Out:
# count    23291.000000
# mean        10.693229
# std          6.560349
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         35.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Снова распределение Пуассона. Медиана - 9 этажей, среднее - 10.7. Минимум - 1 этаж, максимум - 35.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас  трудно определить типовую высотность зданий

# %%
display(data['cityCenters_nearest'].describe())
ax_cityCenters_nearest = data.plot(y = 'cityCenters_nearest', kind = 'hist', 
                                   grid = True, bins = 50, figsize = (15,3));
ax_floors_total.set_xlabel('Общее количество этажей в здании')
ax_floors_total.set_ylabel('Частота');
# Out:
# count    17842.000000
# mean     14247.166181
# std       8605.794196
# min        181.000000
# 25%       9361.750000
# 50%      13138.000000
# 75%      16296.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Большинство квартир находятся в 9361-16296 метров от центра. Но есть как находящиеся у центра квартиры, так и очень удаленные от него, поэтому среднее и медиана почти не различаются ~ 13138-14247 метров.

# %%
display(data['airports_nearest'].describe())
ax_airports_nearest = data.plot(y = 'airports_nearest', kind = 'hist', 
                                grid = True, bins = 60, figsize = (15,3));
ax_airports_nearest.set_xlabel('Расстояние до ближайшего аэропорта')
ax_airports_nearest.set_ylabel('Частота');
# Out:
# count    17821.000000
# mean     28810.671623
# std      12662.289025
# min          0.000000
# 25%      18516.000000
# 50%      26773.000000
# 75%      37310.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Большинство значений лежит в промежутке от 18516 до 37310 метров.

# %%
display(data['parks_nearest'].describe())
ax_parks_nearest = data.plot(y = 'parks_nearest', kind = 'hist', 
                             grid = True, bins = 50, figsize = (15,3));
ax_parks_nearest.set_xlabel('Расстояние до ближайшего парка')
ax_parks_nearest.set_ylabel('Частота');
# Out:
# count    7892.000000
# mean      490.993031
# std       340.588583
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       613.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Большинство квартир из датасета располагаются в 288 - 613 метрах от парка.

# %%
display(data['publication_weekday'].value_counts().sort_index())
# Out:
# 0    3553
# 1    4115
# 2    3896
# 3    4216
# 4    3947
# 5    1902
# 6    1662
# Name: publication_weekday, dtype: int64

# %%
ax_publication_weekday = data['publication_weekday'].value_counts().sort_index().plot(kind='bar');
ax_publication_weekday.set_xlabel('День публикации')
ax_publication_weekday.set_ylabel('Частота');
ax_publication_weekday.set_xticklabels(['Понедельник', 'Вторник', 'Среда', 
                                    'Четверг', 'Пятница', 'Суббота', 'Воскресенье']);

# %%
display(data['publication_month'].value_counts().sort_index())
ax_publication_month = data['publication_month'].value_counts().sort_index().plot(kind='bar')
ax_publication_month.set_xlabel('Месяц публикации')
ax_publication_month.set_ylabel('Частота');
ax_publication_month.set_xticklabels(['Январь', 'Февраль', 'Март', 
                                    'Апрель', 'Май', 'Июнь', 'Июль',
                                     'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь']);
# Out:
# 1     1471
# 2     2594
# 3     2546
# 4     2334
# 5     1248
# 6     1731
# 7     1655
# 8     1721
# 9     1952
# 10    2088
# 11    2341
# 12    1610
# Name: publication_month, dtype: int64

# %% [markdown]
# С датой и месяцем поступаем как с категориальными данными - смотрим на частоту встречаемости значений и строим столбчатые диаграммы. Объявления чаще всего выклыдвают в будние дни, а пик в течение года выпадает на февраль-апрель. В мае происходит резкий спад в появлении новых объявлений и дальше постепенное увеличение их количества к ноябрю. Декабрь и январь также характеризуются низким количеством новых объявлений, что может связано с тем, что люди в этот период вкладывают деньги в праздники (например, в поездки). Также в начале января будут сложности с тем, чтобы взять кредит/ипотеку из-за того, что банки закрыты или работают с сокращенном режиме. Поэтому ближе к февралю все, кто раздумывал взять квартиру на протяжении декабря-января, могут заняться покупкой.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит смотреть на цифры и графики
#
# Можно посмотреть на каждый февраль из нашей выборки, а затем на каждый день особого февраля ...

# %% [markdown]
# __Вывод по общему описанию параметров:__ во всех переменных с указанием метража есть выбивающиеся переменные, на которые нужно будет обратить внимание при дальнейшем анализе.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %% [markdown]
# #### Время показа объявления

# %%
display(data['days_exposition'].describe())
ax_days_exposition = data.plot(y = 'days_exposition', kind = 'hist',
                               grid = True, bins = 100, figsize = (15,3));
ax_days_exposition.set_xlabel('Время показа объявления')
ax_days_exposition.set_ylabel('Частота');
# Out:
# count    20163.000000
# mean       178.995437
# std        214.825993
# min          3.000000
# 25%         45.000000
# 50%         95.000000
# 75%        230.000000
# max       1368.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Большинство объявлений снимают в период с 45 по 230 день, то есть от полутора до восьми месяцев. Минимальное значение 3 дня, а максимальное - 1368 (около 4х лет). Эти значения сильно выбиваются из остальных данных. Посмотрим поподробнее на концы распределения.

# %%
ax_days_exposition_left = data.plot(y = 'days_exposition', kind = 'hist', 
                                    grid = True, range = (0, 45), bins = 20, figsize = (15,3));
ax_days_exposition_left.set_xlabel('Время показа объявления')
ax_days_exposition_left.set_ylabel('Частота');

# %% [markdown]
# На графике видно, что в период от до 30 дней снимается достаточно много объявлений. Вряд ли квартиры так быстро распродаются и стоит рассмотреть гипотезу о других причинах, например, владелец продал ее другим путем или передумал выставлять на продажу.

# %%
ax_days_exposition_right = data.plot(y = 'days_exposition', kind = 'hist', 
                                     grid = True, range = (232, 1580), bins = 20, figsize = (15,3));
ax_days_exposition_left.set_xlabel('Время показа объявления')
ax_days_exposition_left.set_ylabel('Частота');

# %%
data['days_exposition'].mode()
# Out:
# 0    45.0
# dtype: float64

# %% [markdown]
# Мода снятия объявлений - 45й день, если мы посмотрим на правила выставления объявлений в Яндекс Недвижимость, то увидим, что для сделок до 4,5 млн срок размещения объявления о продаже именно 45 дней. Для сделок на более крупные суммы сроки публикации могут быть 60 и 90 дней.

# %% [markdown]
# Частота появления значений резко падает после года, а значения больше двух лет встречаются совсем редко.

# %%
data.pivot_table(index = 'publication_year', values = 'days_exposition', aggfunc = 'mean')\
.round(decimals = 2)
# Out:
#                   days_exposition
# publication_year
# 2014                       855.82
# 2015                       636.44
# 2016                       321.44
# 2017                       158.66
# 2018                        94.19
# 2019                        31.04

# %% [markdown]
# Как видно из сводной таблицы, с каждым годом среднее время показа объявлений сокращалось, что может быть связано как с увеличением популярности сервиса и сделок через интернет, так и с изменениями в правилах размещения объявлений.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Только использовать с осторожностью, у нас еще больше 3000 непроданных квартир, которых нет в статистике о средней скорости продаж

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# #### Оценка факторов, влияющих на полную стоимость объекта.

# %% [markdown]
# Для изучения того, какие факторы влияют на стоймость квартиры, сначала построим корреляционную матрицу и округлим значения до сотых. Воспользуемся столбцом, в котором мы выразили цены в тысячах.

# %%
corr_data = data[['last_price_thousands', 'total_area', 'living_area', 'kitchen_area', 'rooms',
                                        'publication_year']].corr().round(decimals = 2)
corr_data
# Out:
#                       last_price_thousands  total_area  living_area  \
# last_price_thousands                  1.00        0.74         0.65
# total_area                            0.74        1.00         0.93
# living_area                           0.65        0.93         1.00
# kitchen_area                          0.56        0.58         0.36
# rooms                                 0.45        0.79         0.87
# publication_year                     -0.05       -0.09        -0.07
#
#                       kitchen_area  rooms  publication_year
# last_price_thousands          0.56   0.45             -0.05
# total_area                    0.58   0.79             -0.09
# living_area                   0.36   0.87             -0.07
# kitchen_area                  1.00   0.22             -0.06
# rooms                         0.22   1.00             -0.05
# publication_year             -0.06  -0.05              1.00

# %% [markdown]
# Ориентируясь на первую строку можем сказать, что цена объекта умеренно коррелирует с общей площадю, жилой площадью. Есть также слабая корреляция с количеством комнат.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %% [markdown]
# Строить матрицу диаграмм рассеяния не будем, так как это будет не очень удобно, поэтому построим их по очереди.

# %%
ax_price_total_area = data.plot(x = 'total_area', y = 'last_price_thousands', kind='scatter',
                                alpha = 0.1, figsize = (15,3));
ax_price_total_area.set_xlabel('Общая площадь')
ax_price_total_area.set_ylabel('Цена (в тысячах)');

# %% [markdown]
# На диаграмме рассеяния видно, что при увеличении общей площади объекта увеличивается и его цена. Попробуем убрать выбросы, которые мы ранее обнаружили среди значений общей площади и посмотрим ближе на цену квартир площадью до 200м<sup>2</sup>.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %%
data.loc[data['total_area'] < 200, 'total_area']
# Out:
# 0        108.00
# 1         40.40
# 2         56.00
# 3        159.00
# 4        100.00
#           ...
# 23694    133.81
# 23695     59.00
# 23696     56.70
# 23697     76.75
# 23698     32.30
# Name: total_area, Length: 23188, dtype: float64

# %%
ax_price_total_area_200 = data.plot(x = 'total_area', y = 'last_price_thousands', kind='scatter',
                                alpha = 0.1, figsize = (15,3));
ax_price_total_area_200.set_xlabel('Общая площадь')
ax_price_total_area_200.set_ylabel('Цена (в тысячах)');
plt.xlim(0, 200);

# %% [markdown]
# Мы видим не резкий, но стабильный подъем цены при возрастании площади квартиры, несколько выбросов в цене в районе 100-150 миллионов рублей (переводим цену из указанных тысяч) и выше 250 миллионов рублей. Связь более четкая, чем при рассмотрении полных ранных.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Далее построим такой же график и для других переменных.

# %%
ax_price_living_area = data.plot(x = 'living_area', y = 'last_price_thousands', 
                                 kind='scatter', alpha = 0.2, figsize = (15,3))
ax_price_living_area.set_xlabel('Жилая площадь')
ax_price_living_area.set_ylabel('Цена (в тысячах)');

# %%
ax_price_kitchen_area = data.plot(x = 'kitchen_area', y = 'last_price_thousands', 
                                  kind='scatter', alpha = 0.2, figsize = (15,3))
ax_price_kitchen_area.set_xlabel('Площадь кухни')
ax_price_kitchen_area.set_ylabel('Цена (в тысячах)');

# %% [markdown]
# Ту же связь цены и площади мы видим и при построении графиков с жилой и кухонной площадями. Однако в обоих случаях мы видим менее четкую связь из-за большего разброса данных. Строить урезанные графики для этих переменных мы уже не будем.

# %%
ax_price_rooms = data.plot(x = 'rooms', y = 'last_price_thousands', kind='scatter', alpha = 0.2,
                           figsize = (15,3))
ax_price_rooms.set_xlabel('Количество комнат')
ax_price_rooms.set_ylabel('Цена (в тысячах)');

# %%
pt_price_rooms = data.pivot_table(index = 'rooms', values = 'sqr_meter_price', 
                                    aggfunc = ['count', 'median'])
pt_price_rooms.round(decimals = 2)
# Out:
#                 count          median
#       sqr_meter_price sqr_meter_price
# rooms
# 0                 182       105050.19
# 1                7926       100000.00
# 2                7856        92758.74
# 3                5758        88888.89
# 4                1154        92303.80
# 5                 290        94110.42
# 6                  81        95454.55
# 7                  37       106398.10
# 8                   7        94626.72

# %% [markdown]
# Связь количества комнат и цены непрямая. Это подтверждает и низкий коэффициент корреляции, который мы посчитали выше.
#
# Важно отметить, что количество наблюдений сильно варьируется. Если посмотреть на медианы для категорий, где больше всего наблюдений (1-4 комнат), то больше всего выбивается цена за квадратный метр для трехкомнатных квартир - она самая низкая, а для однокомнатных - самая высокая.

# %%
pt_price_floor_category = data.pivot_table(index = 'floor_category', values = 'last_price_thousands',
                                          aggfunc = 'median')
pt_price_floor_category
# Out:
#                 last_price_thousands
# floor_category
# другой                        4800.0
# первый                        3900.0
# последний                     4300.0

# %%
ax_price_floor_category = pt_price_floor_category.plot(kind='barh', alpha = 0.7, legend = False);
#.plot(x = 'floor_category', y = 'last_price_thousands', kind='scatter', alpha = 0.2)
ax_price_floor_category.set_ylabel('Площадь кухни')
ax_price_floor_category.set_xlabel('Цена (в тысячах)');

# %% [markdown]
# Исходя из графика можно сказать, что дешевле всего квартиры на первом этаже, а дороже - на средних этажах.

# %%
pt_price_weekday = data.pivot_table(index = 'publication_weekday', 
                                    values = 'last_price_thousands', aggfunc = 'median')
pt_price_weekday
# Out:
#                      last_price_thousands
# publication_weekday
# 0                                  4650.0
# 1                                  4700.0
# 2                                  4700.0
# 3                                  4600.0
# 4                                  4550.0
# 5                                  4500.0
# 6                                  4540.0

# %%
ax_price_weekday = pt_price_weekday.plot(kind='barh', alpha = 0.7, legend = False);
ax_price_weekday.set_ylabel('День публикации')
ax_price_weekday.set_xlabel('Цена (в тысячах)');
ax_price_weekday.set_yticklabels(['Понедельник', 'Вторник', 'Среда', 
                                    'Четверг', 'Пятница', 'Суббота', 'Воскресенье']);
plt.xlim(3000, 5000);

# %%
pt_price_month = data.pivot_table(index = 'publication_month', 
                                    values = 'last_price_thousands', aggfunc = 'median')
pt_price_month
# Out:
#                    last_price_thousands
# publication_month
# 1                                4600.0
# 2                                4650.0
# 3                                4645.0
# 4                                4785.0
# 5                                4500.0
# 6                                4400.0
# 7                                4650.0
# 8                                4590.0
# 9                                4694.5
# 10                               4550.0
# 11                               4680.0
# 12                               4700.0

# %%
ax_price_month = pt_price_month.plot(kind='barh', alpha = 0.7, legend = False);
ax_price_month.set_ylabel('Месяц публикации')
ax_price_month.set_xlabel('Цена (в тысячах)');
ax_price_month.set_yticklabels(['Январь', 'Февраль', 'Март', 
                                    'Апрель', 'Май', 'Июнь', 'Июль',
                                     'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь']);
plt.xlim(4000, 5000);

# %% [markdown]
# Средняя цена находится примерно на одном уровне в течение года. Попробуем посмотреть на ее изменения для определенной категории квартир - тех, чья площадь находится в рамках межквартильного размаха.

# %%
pt_price_month_tota_area_40_69 = (data.query('total_area >= 40 and total_area <= 69')
                                  .pivot_table(index = 'publication_month', 
                                               values = 'last_price_thousands', aggfunc = 'median'))
pt_price_month_tota_area_40_69
# Out:
#                    last_price_thousands
# publication_month
# 1                                4599.0
# 2                                4600.0
# 3                                4592.0
# 4                                4700.0
# 5                                4550.0
# 6                                4350.0
# 7                                4600.0
# 8                                4520.0
# 9                                4650.0
# 10                               4550.0
# 11                               4600.0
# 12                               4590.0

# %% [markdown]
# Разница между месяцами особо не поменялась.

# %%
pt_price_year = data.pivot_table(index = 'publication_year', values = 'last_price_thousands', 
                                    aggfunc = 'median')
pt_price_year
# Out:
#                   last_price_thousands
# publication_year
# 2014                            7500.0
# 2015                            5250.0
# 2016                            4500.0
# 2017                            4500.0
# 2018                            4575.0
# 2019                            5047.0

# %%
ax_price_year = pt_price_year.plot(kind='barh', alpha = 0.7, legend = False);
ax_price_year.set_ylabel('Год публикации')
ax_price_year.set_xlabel('Цена (в тысячах)');

# %%
pt_price_year_area = data.pivot_table(index = ['publication_year', 'floor_category'], 
                                    aggfunc = {'last_price_thousands': ['median', 'count'],
                                               'total_area': 'median',
                                              'sqr_meter_price': 'median'})
pt_price_year_area.round(decimals = 2)
# Out:
#                                 last_price_thousands          sqr_meter_price  \
#                                                count   median          median
# publication_year floor_category
# 2014             другой                           92   7950.0       112343.47
#                  первый                           13   5400.0        85714.29
#                  последний                        21  16137.0       137167.54
# 2015             другой                          812   5550.0        97108.81
#                  первый                          159   4200.0        80378.25
#                  последний                       177   4700.0        89871.61
# 2016             другой                         1982   4750.0        95092.60
#                  первый                          371   3900.0        78633.98
#                  последний                       382   4225.0        85418.12
# 2017             другой                         5970   4650.0        95652.17
# ...

# %% [markdown]
# Количество объявлений в первый год было очень маленьким и остальные статистики выбиваются из общего тренда. Для последующих годов значимо меналось только количество объявлений (резкое возрастание в 2017-2018), общая цена и цена за квадратный метр плавно повышались с 2016 по 2019 год каждого типа этажа, на котором располагались квартиры.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __можно заметить что в 2018 году доля квартир на первом этаже от общего кол-ва составляет 12,3%, а в 2019 году 8,7%. Это может объяснить рост средней цены в 2019 году__
#
# цифры могут поменяться, у нас осталось всего 10000 записей
#
# ![image.png](attachment:image.png)

# %% [markdown]
# __Вывод:__ исходя из построенных диаграмм рассеяния можно сделать вывод, что на цену больше всего влияют площади объектов: чем больше площадь, тем выше цена. Цена также частично связана с количеством комнат, но эта связь непрямая. Цена также варьируется в зависимости от этажа: дешевле всего - на первом, а дороже - на средних этажах.
#
# Исходя из данных по годам можно сказать, что цена плавно повышается, если смотреть на общий тренд. Ниже рассмотрим квартиры для отдельных населенных пунктов.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит поменять тип у последних 5-ти графиков
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам:
#
# + зависимость параметров (от площади, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)
#
#         А для того, чтобы лучше рассмотреть связь цены и года мы приблизили график. Разброс в ценах повышался с 2014 по 2017 год, а затем снизился к 2019 году.

# %% [markdown]
# #### Средняя цена квадратного метра в популярных населенных пунктах

# %%
location_meter_price = data.pivot_table(index = 'locality_name', 
                                        values = 'sqr_meter_price', 
                                        aggfunc = ['count', 'mean']).reset_index()
location_meter_price.columns = ['locality_name', 'count', 'mean']
location_meter_price_head = location_meter_price.sort_values(by = 'count', ascending = False).head(10)
location_meter_price_head.round(decimals = 2)
# Out:
#          locality_name  count       mean
# 34     Санкт-Петербург  15411  113232.05
# 228     посёлок Мурино    545   85535.09
# 301     посёлок Шушары    437   78554.91
# 4           Всеволожск    396   68735.60
# 33              Пушкин    361  102860.66
# 14             Колпино    337   75333.30
# 238  посёлок Парголово    322   90054.07
# 7              Гатчина    307   68746.15
# 92     деревня Кудрово    299   92473.55
# 5               Выборг    235   58238.14

# %%
ax_location_meter_price = location_meter_price_head.loc[:, ['locality_name', 'mean']]\
.plot(x = 'locality_name', y = 'mean',
    kind='barh', alpha = 0.7, legend = False);
ax_location_meter_price.set_xlabel('Населенный пункт')
ax_location_meter_price.set_ylabel('Цена за кв. метр');

# %% [markdown]
# Больше всего объявлений оказалось в следующих местах: Санкт-Петербург, посёлки Мурино и Шушары, Всеволожск, Пушкин, Колпино, посёлок Парголово, Гатчина, деревня Кудрово, Выборг.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график, для заливки баров стоит выбрать цвет на несколько тонов поярче
#
#      kind='barh'

# %%
location_meter_price_head.sort_values(by = 'mean').round(decimals = 2)
# Out:
#          locality_name  count       mean
# 5               Выборг    235   58238.14
# 4           Всеволожск    396   68735.60
# 7              Гатчина    307   68746.15
# 14             Колпино    337   75333.30
# 301     посёлок Шушары    437   78554.91
# 228     посёлок Мурино    545   85535.09
# 238  посёлок Парголово    322   90054.07
# 92     деревня Кудрово    299   92473.55
# 33              Пушкин    361  102860.66
# 34     Санкт-Петербург  15411  113232.05

# %% [markdown]
# Среди этих мест самая низкая средняя стоимость квадратного метра в Выборге - 58238 рублей, а самая высокая в Санкт-Петербурге - 113232 рублей за квадратный метр.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         деревня Кудрово	299	92473.547576
#         Пушкин	369	103125.819291
#         Санкт-Петербург	15721	114849.008794

# %%
sqr_meter_price_min = data['sqr_meter_price'].min()
data.loc[data['sqr_meter_price'] == sqr_meter_price_min, ['locality_name', 'sqr_meter_price']]\
.round(decimals = 2)
# Out:
#       locality_name  sqr_meter_price
# 23477       Гатчина         10507.25

# %%
sqr_meter_price_max = data['sqr_meter_price'].max()
data.loc[data['sqr_meter_price'] == sqr_meter_price_max, ['locality_name', 'sqr_meter_price']]\
.round(decimals = 2)
# Out:
#         locality_name  sqr_meter_price
# 4996  Санкт-Петербург        995983.94

# %% [markdown]
# Если мы посмотрим на минимальную и максимальную цену за квадратный метр по всей выборке, то увидим, что самая низкая цена принадлежит Гатчине - 10507 рублей, а самая высокая Санкт-Петербургу - 995983 рубля.

# %% [markdown]
# __Вывод:__ В большом городе выше цена, что может быть связано с большими возможностями в плане работы, развитой инфраструктуры и социальной жизни.

# %% [markdown]
# #### Оценка стоимости квартир Санкт-Петербурга

# %% [markdown]
# Выберем значения местности "Санкт-Петербург" и построим сводные таблицы для выяснения средних цен по каждому километру.

# %%
spb_data = data.loc[data['locality_name'] == 'Санкт-Петербург']

# %%
pt_spb_km_price = spb_data.pivot_table(index = 'cityCenters_km', 
                                       values = 'last_price_thousands', 
                                       aggfunc = ['mean', 'count']).reset_index()
pt_spb_km_price.round(decimals = 2)
# Out:
#    cityCenters_km                 mean                count
#                   last_price_thousands last_price_thousands
# 0               0             21887.09                   23
# 1               1             14914.34                  177
# 2               2             15222.94                  298
# 3               3             10385.54                  338
# 4               4             11146.67                  670
# 5               5             12067.97                  874
# 6               6             12342.58                  588
# 7               7             13500.03                  409
# 8               8              8938.73                  583
# 9               9              6964.46                  587
# 10             10              6404.92                  712
# 11             11              6159.57                 1160
# 12             12              5803.30                 1588
# 13             13              6071.24                 1442
# ...

# %%
ax_spb_km_price = pt_spb_km_price.loc[:, ['cityCenters_km', 'mean']]\
.plot(kind='bar', alpha = 0.2, color = 'blue', legend = False, figsize = (15,3));
ax_spb_km_price.set_xlabel('Километр')
ax_spb_km_price.set_ylabel('Цена (в тысячах)');
ax_spb_km_price.set_xticklabels(labels = range(0, 30), rotation=0);

# %% [markdown]
# Больше всего наблюдей находится на 4-17-м километре. Заметен резкий подъем с 4-го по 7-й километр, а затем резкий спад на 8-9 километре и дальше цена варьируется примерно в одном небольшом проежутке до 17-го километра.
#
# Выбросы на 0 и 27 километре могут объясняться маленьким количеством наблюдений.

# %%
pt_3_5km = data.query('cityCenters_km in [1, 2, 3, 4, 5, 6] and locality_name == "Санкт-Петербург"')\
.pivot_table(index = ['cityCenters_km', 'floor_category'], 
             aggfunc = {'last_price_thousands': ['count', 'mean'], 
                        'total_area': 'mean'}).round(decimals = 2)
pt_3_5km
# Out:
#                               last_price_thousands           total_area
#                                              count      mean       mean
# cityCenters_km floor_category
# 1              другой                          111  15548.47      96.08
#                первый                           24  15238.71      95.36
#                последний                        42  13053.10      93.64
# 2              другой                          176  16965.59     101.62
#                первый                           44   9117.02      74.98
#                последний                        78  14735.17     100.61
# 3              другой                          208  11274.66      90.32
#                первый                           53   7528.68      67.22
#                последний                        77   9950.18      88.86
# 4              другой                          482  11573.50      89.93
#                первый                           77   7727.66      68.77
# ...

# %% [markdown]
# Первые два километра относятся к центру города, поэтому цены закономерно выше. С 3-го по 5-й километр происходит резкий подъем цен. Это может объясняться пропорциями категорий квартир - на 3-м километре доля квартир с более высокой ценой (на средних этажах) значительно меньше.

# %% [markdown]
# __Вывод:__ В центре цены заметно выше. Резкое изменение цен на 3-7-м километрах может быть связано с пропорциями более дорогих и дешевых категорий квартир: доля квартир на средних этажах увеличивается к 5-7 километру.
#
# Далее при отдалении от центра цены закономерно снижаются и держатся примерно на одном уровне с 11 по 23-й километр.
#
# Выбивающиеся значения после 26-го километра объясняются малым количеством объявлений, которые не дают репрезентативной выборки.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены в зависимости от расстояния до центра

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + Стоит изучить записи, которые привели к выбросу на 27-м км.
#
# Принимается: у нас всего 2 записи на 27-м км., одна из которых с аномальной ценой, по этой причине мы отвергаем данное наблюдение
#
# кол-во наблюдений важный параметр для оценки качества данных
#
# + про пик и взлет на 3-м и 5-м километрах,  подправим акценты вывода
#
# Две стопки монет: в одной 8 золотых и 2 серебряные, во второй 6 золотых и 4 серебряные. В какой стопке средняя цена одной монеты будет дороже?
#
# Размер доли категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />мы сравниваем 3-ий км. и 5-ый
#
# на втором километре свои правила, это сердце центра, а на 3-5 км. другие правила
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поняла) Добавила в результаты

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# При анализе данных сервиса Яндекс Недвижимость мы обнаружили закономерности, связанные с публикацией объявлений и образованием цен.
# Во-первых, мы выявлили, что чаще всего объявления публикуют в будние дни, а пик в течение года приходится на февраль-апрель.
#
# Во-вторых, большинство объявлений снимают с публикации в период с 45 по 232 день. При этом снятие объявлений на 45, 60 и 90-й день обусловлено правилами сервиса - это сроки публикации объявлений для разных типов сделок. В течение первого месяца снимают неожиданно много объявлений, особенно это странно для первых 5-10 дней. Причиной снятия квартиры с пордажи может быть не только тот факт, что на платформе нашелся покупатель. Владельцы могли передумать пользоваться данным сервисом или в принципе продавать квартиру. Это может касаться как раз тех объявлений, которые сняли в первые дни.
#
# В-третьих, мы обнаружили корреляцию цены с площью квартиры в целом, а также жилой части квартиры и кухни. Более дешевые квартиры располагаются на первом этаже, а более дорогие - на средних.В количеством комнат четкой связи мы не увидели. Кроме того, данные показали, что из года в год количество объявлений повышалось, а цена на квартиры поднималась достаточно плавно с 2016 по 2019 год.
#
# В конце мы проверили в каких населенных пунктах цены больше всего объявлений и как меняется цена, в зависимости от локации. Больше всего объявлений было в Санкт-Петербурге, где также оказались самые высокие цены за один квадратный метр в среднем. При этом цены уменьшаются при удалении от центра города, выбросы в средней цене связаны с пропорциями квартир разных категорий и недостаточным количеством наблюдений.
#
# В дальнейшем можно будет посмотреть на параметры конкретно за последние годы, так как они лучше будут отражать реальные цены и тренды в типах квартир, и сравнить их с общим анализом, чтобы определить изменения.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнила исследовательскую работу, молодец, показала хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + отформатировать неявные дубликаты
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы в п.4.1
# + подправить графики в п. 4.3
# + добавить вывод в п. 4.3
# + добавить график в ТОП-10
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На примере ниже я покажу как фильтровать записи с пропусками
#
#
# Мягкие условия для удаления через логическую операцию или: оставляем все пропуски или все значения, которые ближе чем 60 000 метров
#
#         df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
#
# В изначальном датасете было всего записей — 23699 entries, из них заполненные
#
#             15  airports_nearest      18157 non-null  float64
#
# Осталось — 23525 entries, из них заполненные
#
#             15  airports_nearest      17983 non-null  float64
#
# т.е. все пропуски в столбце airports_nearest остались на месте
#
# Знак | обозначает логическую операцию «или», иногда мы ее записываем при помощи оператора «or»

# %%
# check
try:
    df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')
    
df_check.info()
df_isna = df_check.query('airports_nearest.isna() | airports_nearest < 60000')
df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример второго варианта фильтрации колонок с пропусками, в обновленной версии библиотеки пандас первый вариант работать, возможно, не будет

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 
df_check.info()
df_isna = df_check[(df_check ['airports_nearest'] < 60000) | (df_check ['airports_nearest'].isna()) ]

df_isna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример фильтрации колонок с пропусками по промежуткам

# %%
# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 

# check
df_check = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') 

df_check = df_check[
    (
        (df_check['airports_nearest'] < 70000) | (df_check['airports_nearest'].isna())
    ) & 
    (
        (df_check['airports_nearest'] > 40000) | (df_check['airports_nearest'] < 30000) | (df_check['airports_nearest'].isna())
    ) 
   ]

# %%
df_check['airports_nearest'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
df_check.drop(df_check.query('15000 < airports_nearest < 22000').index,inplace=True)

# %%
df_check['airports_nearest'].hist(bins = 100);

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15770 entries, 1 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          15770 non-null  int64
#  1   last_price            15770 non-null  float64
#  2   total_area            15770 non-null  float64
#  3   first_day_exposition  15770 non-null  object
#  4   rooms                 15770 non-null  int64
#  5   ceiling_height        9435 non-null   float64
#  6   floors_total          15710 non-null  float64
#  7   living_area           14442 non-null  float64
#  8   floor                 15770 non-null  int64
#  9   is_apartment          1828 non-null   object
#  10  studio                15770 non-null  bool
#  11  open_plan             15770 non-null  bool
#  12  kitchen_area          14175 non-null  float64
#  13  balcony               8063 non-null   float64
#  14  locality_name         15735 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все пропуски сохранены

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
