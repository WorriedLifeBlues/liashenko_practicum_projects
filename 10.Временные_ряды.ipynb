# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#LightGBM" data-toc-modified-id="LightGBM-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>LightGBM</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# В ходе проекта мы должны выяснить, какая модель быстрее и точнее сможет предсказать количество заказов такси в следующий час. Сначала мы подготовим и проанализируем данные - проверим их на тренды и сезонность. Затем проверим результаты работы модели дерева решений, линейной регрессии и модели LightGBM с несколькими вариантами гиперпараметров. В конце выберем лучшую модель на основании самой низкой среднеквадратичной ошибки.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# ## Подготовка

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter, MO, TU, WE, TH, FR, SA, SU
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import lightgbm as lgb
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor

# %%
plt.rcParams.update({'font.size': 14})

# %%
try:
    data_raw = pd.read_csv('/datasets/taxi.csv', index_col = [0], parse_dates = [0])
except:
    data_raw = pd.read_csv('https://code.s3.yandex.net/datasets/taxi.csv', index_col = [0], parse_dates = [0])

# %%
data_raw.sort_index(inplace = True)
data_raw.head(10)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# 2018-03-01 00:50:00          21
# 2018-03-01 01:00:00           7
# 2018-03-01 01:10:00           5
# 2018-03-01 01:20:00          17
# 2018-03-01 01:30:00          12

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %% [markdown]
# ## Анализ

# %%
data = data_raw.resample('1H').sum()

plt.figure(figsize=(10, 6))
plt.xlabel("Месяцы")
plt.ylabel("Количество заказов")
plt.plot(data)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# Среднее и разброс данных изменяются, значит временной ряд не стационарный.
# Проверим тренд и сезонность.

# %%
decomposed = seasonal_decompose(data)


figure, axis = plt.subplots(3, figsize=(15, 15))
figure.tight_layout(pad=5.0)

axis[0].plot(decomposed.trend)
axis[0].set_title("Тренд")

axis[1].plot(decomposed.seasonal)
axis[1].set_title("Сезонность")

axis[2].plot(decomposed.resid)
axis[2].set_title("Остаток")

for ax in axis.flat:
    ax.set(xlabel='Месяц', ylabel='Количество заказов')
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

plt.show()

# %% [markdown]
# Общий тренд показывает увеличение заказов к концу выбранного периода. Чтобы рассмотреть сезонность, попробуем построить графики изменения в количестве заказов в течение дня за последнюю неделю.

# %%
decomposed = seasonal_decompose(data.loc['2018-08-25':'2018-08-31'])

figure, axis = plt.subplots(3, figsize=(15, 15))
figure.tight_layout(pad=5.0)

axis[0].plot(decomposed.trend)
axis[0].set_title("Тренд")
axis

axis[1].plot(decomposed.seasonal)
axis[1].set_title("Сезонность")

axis[2].plot(decomposed.resid)
axis[2].set_title("Остаток")

for ax in axis.flat:
    ax.set(xlabel='День', ylabel='Количество заказов')
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=(MO, TU, WE, TH, FR, SA, SU)))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

plt.show()

# %% [markdown]
# Общий тренд показывает, что в воскресенье и в середине недели количество заказов падает, а в понедельник и к концу недели резко возрастает. Также мы видим сезонность по дням - закономерность в изменении количества заказов в течение суток каждый день.

# %% [markdown]
# Возьмем последний месяц. Посмотрим на тренд и сезонность, а затем на скользящее среднее.

# %%
decomposed = seasonal_decompose(data.loc['2018-08-01':'2018-08-31'])

figure, axis = plt.subplots(3, figsize=(15, 10))
figure.tight_layout(pad=5.0)

axis[0].plot(decomposed.trend)
axis[0].set_title("Тренд")
axis

axis[1].plot(decomposed.seasonal)
axis[1].set_title("Сезонность")

axis[2].plot(decomposed.resid)
axis[2].set_title("Остаток")

for ax in axis.flat:
    ax.set(xlabel='День', ylabel='Количество заказов')
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=(MO, TU, WE, TH, FR, SA, SU)))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'))

plt.show()

# %%
data.head(20)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# 2018-03-01 05:00:00           6
# 2018-03-01 06:00:00          12
# 2018-03-01 07:00:00          15
# 2018-03-01 08:00:00          34
# 2018-03-01 09:00:00          69
# 2018-03-01 10:00:00          64
# 2018-03-01 11:00:00          96
# 2018-03-01 12:00:00          30
# 2018-03-01 13:00:00          32
# 2018-03-01 14:00:00          48
# 2018-03-01 15:00:00          66
# 2018-03-01 16:00:00          43
# 2018-03-01 17:00:00          44
# 2018-03-01 18:00:00          73
# 2018-03-01 19:00:00          45

# %%
data['rolling_mean'] = data['num_orders'].rolling(7).mean()
data['std'] = data['num_orders'].rolling(7).std()

plt.figure(figsize=(15, 10))
plt.xlabel("Дни")
plt.ylabel("Количество заказов")
plt.plot(data.loc['2018-08-01':'2018-08-31'])

# %%
data = data.drop(['rolling_mean', 'std'], axis = 1)
data.columns
# Out:
# Index(['num_orders'], dtype='object')

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# data['rolling_mean'] и data['std'] нужно удалить после проведения EDA, так не будет утечки

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Убрала
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# Предположительно на количество заказов в сильно влияет день недели и время дня - на всех графиках мы видим сильный разброс даже при усреднении.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Декомпозиция сделана верно. Хорошо, что сезонность была визуализирована на более коротком интервале)

# %% [markdown]
# ## Обучение

# %% [markdown]
# Создадим признаки для обучения.

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
        
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %%
make_features(data, 24, 7)

# %%
data = data.dropna()
data.head()
# Out:
#                      num_orders  dayofweek  hour  lag_1  lag_2  lag_3  lag_4  \
# datetime
# 2018-03-02 00:00:00          90          4     0   58.0  113.0   66.0   61.0
# 2018-03-02 01:00:00         120          4     1   90.0   58.0  113.0   66.0
# 2018-03-02 02:00:00          75          4     2  120.0   90.0   58.0  113.0
# 2018-03-02 03:00:00          64          4     3   75.0  120.0   90.0   58.0
# 2018-03-02 04:00:00          20          4     4   64.0   75.0  120.0   90.0
#
#                      lag_5  lag_6  lag_7  ...  lag_16  lag_17  lag_18  lag_19  \
# datetime                                  ...
# 2018-03-02 00:00:00   45.0   73.0   44.0  ...    34.0    15.0    12.0     6.0
# 2018-03-02 01:00:00   61.0   45.0   73.0  ...    69.0    34.0    15.0    12.0
# 2018-03-02 02:00:00   66.0   61.0   45.0  ...    64.0    69.0    34.0    15.0
# 2018-03-02 03:00:00  113.0   66.0   61.0  ...    96.0    64.0    69.0    34.0
# ...

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Тут следует написать функцию, которая возвращает новый датафрейм с новыми признаками. Нужно добавить календарные признаки (час и день недели) и отстающие (лаги и скользящее среднее). Далее сгенерировать новые признаки этой функцией и уже вместе с ними обучать модели. Еще заранее предупрежу, что скользящее среднее использует текущее значение, поэтому будет необходимо вызвать shift() перед rolling

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Метрика на тесте должна быть ниже 48, поэтому стоит попробовать задать параметр max_lag равным 24 при создании новых признаков функцией. В случае заказов такси самая очевидная сезонность - внутри суток, а в сутках 24 часа, это значение и будет оптимальным

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Спасибо, добавила
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
features = data.drop(['num_orders'], axis = 1)
target = data['num_orders']

# %%
target_train, target_test, features_train, features_test = train_test_split(
    target, features, shuffle=False, test_size=0.1)
for data in [features_train,
             target_train,
             features_test,
             target_test]:
    print(data.shape)
# Out:
# (3952, 27)
# (3952,)
# (440, 27)
# (440,)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %% [markdown]
# Масштабируем признаки.

# %%
features.columns
# Out:
# Index(['dayofweek', 'hour', 'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5',
#        'lag_6', 'lag_7', 'lag_8', 'lag_9', 'lag_10', 'lag_11', 'lag_12',
#        'lag_13', 'lag_14', 'lag_15', 'lag_16', 'lag_17', 'lag_18', 'lag_19',
#        'lag_20', 'lag_21', 'lag_22', 'lag_23', 'lag_24', 'rolling_mean'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaler.fit(features_train)
features_train = pd.DataFrame(scaler.transform(features_train), columns = features.columns)
features_test = pd.DataFrame(scaler.transform(features_test), columns = features.columns)

# %%
features_train.head()
# Out:
#    dayofweek      hour     lag_1     lag_2     lag_3     lag_4     lag_5  \
# 0   0.485927 -1.659738 -0.528019  0.893921 -0.320922 -0.450002 -0.863303
# 1   0.485927 -1.515209  0.299361 -0.528062  0.894380 -0.320716 -0.449476
# 2   0.485927 -1.370681  1.075030  0.299273 -0.527782  0.894574 -0.320155
# 3   0.485927 -1.226152 -0.088473  1.074900  0.299658 -0.527574  0.895464
# 4   0.485927 -1.081624 -0.372885 -0.088540  1.075383  0.299858 -0.527069
#
#       lag_6     lag_7     lag_8  ...    lag_16    lag_17    lag_18    lag_19  \
# 0 -0.138632 -0.888637 -0.914121  ... -1.158687 -1.658000 -1.735774 -1.892353
# 1 -0.863199 -0.138050 -0.888241  ... -0.238808 -1.158312 -1.656894 -1.734622
# 2 -0.449161 -0.862755 -0.137723  ... -0.370219 -0.237833 -1.157327 -1.655756
# 3 -0.319774 -0.448638 -0.862361  ...  0.470813 -0.369330 -0.237070 -1.156273
# 4  0.896462 -0.319226 -0.448282  ... -1.263816  0.472251 -0.368535 -0.236172
#
# ...

# %% [markdown]
#  <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера  <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# </b> Ячейка выше не отработала. Перед отправкой проекта стоит проверять работоспособность кода - это можно сделать, нажав на панели Jupiter Hub `Kernel` и `Restart & Run All`. Исправь, пожалуйста.

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Исправила
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# Проверим алгоритмы решающего дерева, линейной регрессии и LightLGBM.

# %% [markdown]
# ### Решающее дерево

# %%
state = 12345

# %%
tscv = TimeSeriesSplit(n_splits = 5)

# %%
# %%time
pipeline = Pipeline(steps = [
    ("model_dtr", DecisionTreeRegressor(random_state=state))])

parameters = {'model_dtr__max_depth': [2, 5, 10, 20],
      'model_dtr__min_samples_leaf': [1, 2, 4],
      'model_dtr__min_samples_split': [2, 5, 10]}

grid_search_dtr = GridSearchCV(estimator = pipeline, param_grid = parameters, 
                               scoring = 'neg_mean_squared_error', cv = tscv)
grid_search_dtr.fit(features_train, target_train);
# Out:
# CPU times: user 3.38 s, sys: 0 ns, total: 3.38 s
# Wall time: 3.38 s
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=Pipeline(steps=[('model_dtr',
#                                         DecisionTreeRegressor(random_state=12345))]),
#              param_grid={'model_dtr__max_depth': [2, 5, 10, 20],
#                          'model_dtr__min_samples_leaf': [1, 2, 4],
#                          'model_dtr__min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error')

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# При работе с временными рядами не следует использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа нужно передать в параметр cv в метод основанный на кросс-валидации
#
# (это касается абсолютно всех моделей, всех cross_val_score и всех SearchCV)
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Спасибо, добавила это здесь и ниже.
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
print('Лучшие параметры:', grid_search_dtr.best_params_)
print('Лучшая rmse:', abs(grid_search_dtr.best_score_)**0.5)
# Out:
# Лучшие параметры: {'model_dtr__max_depth': 5, 'model_dtr__min_samples_leaf': 4, 'model_dtr__min_samples_split': 2}
# Лучшая rmse: 29.016097263994673

# %% [markdown]
# RMSE лучшей модели решающего дерева соответствует требованию проекта.

# %% [markdown]
# ### Линейная регрессия

# %%
# %%time
model_lr = LinearRegression()
model_lr.fit(features_train, target_train)
predictions = model_lr.predict(features_train)
# Out:
# CPU times: user 26 ms, sys: 159 µs, total: 26.2 ms
# Wall time: 16.2 ms

# %%
rmse = mean_squared_error(target_train, predictions) ** 0.5
rmse
# Out:
# 25.84479533832424

# %% [markdown]
# RMSE линейной регрессии так же меньше 48, что указано в требованиях и ниже, чем у модели решающего дерева.

# %% [markdown]
# ### LightGBM

# %%
# %%time 
pipeline = Pipeline(steps = [
    ("model_lgbm", lgb.LGBMRegressor(random_state=state))])

parameters = {'model_lgbm__max_depth': [2, 5, 10, 20],
      'model_lgbm__n_estimators': [50, 100, 200]}

grid_search_lgbm = GridSearchCV(estimator = pipeline, param_grid = parameters, 
                               scoring = 'neg_mean_squared_error', cv = tscv)
grid_search_lgbm.fit(features_train, target_train);
# Out:
# CPU times: user 27.7 s, sys: 72.8 ms, total: 27.8 s
# Wall time: 3.5 s
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=Pipeline(steps=[('model_lgbm',
#                                         LGBMRegressor(random_state=12345))]),
#              param_grid={'model_lgbm__max_depth': [2, 5, 10, 20],
#                          'model_lgbm__n_estimators': [50, 100, 200]},
#              scoring='neg_mean_squared_error')

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# При работе с временными рядами не следует использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа нужно передать в параметр cv в метод основанный на кросс-валидации
#
# (это касается абсолютно всех моделей, всех cross_val_score и всех SearchCV)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
print('Лучшие параметры:', grid_search_lgbm.best_params_)
print('Лучшая rmse:', abs(grid_search_lgbm.best_score_)**0.5)
# Out:
# Лучшие параметры: {'model_lgbm__max_depth': 5, 'model_lgbm__n_estimators': 100}
# Лучшая rmse: 24.874801040281927

# %% [markdown]
# У данной модели оказалась самая низкая метрика RMSE. Максимальная глубина лучшей модели 20, а количество деревьев - 100. Проверим эту модель далее на тестовой выборке.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ## Тестирование

# %%
model_lgbm = lgb.LGBMRegressor(random_state=state, max_depth = 20, n_estimators = 100)
model_lgbm.fit(features_train, target_train)

predictions_test_lgbm = model_lgbm.predict(features_test)
rmse_lgbm = (mean_squared_error(target_test, predictions_test_lgbm))**0.5

print(f'RMSE LightGBM: {rmse_lgbm}')
# Out:
# RMSE LightGBM: 40.24646686299003

# %% [markdown]
# Результат на тестовой выборке оказался чуть хуже, но все еще в рамках заявленных требований.

# %% [markdown]
# Посмотрим на реальные и предсказанные данные за последний месяц.

# %%
test_plot = pd.DataFrame(target_test)
test_plot['prediction'] = predictions_test_lgbm.tolist()

# %%
fig, ax = plt.subplots(figsize=(15, 7))
ax.plot(test_plot.loc['2018-08-01':'2018-08-31'])
plt.xlabel("Месяцы")
plt.ylabel("Количество заказов")
ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=(MO, TU, WE, TH, FR, SA, SU)))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%a'));

# %% [markdown]
# Предсказанные данные близки к реальным, но не учитывают внезапных скачков.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В конце проекта желательно визуализировать результаты (построить 2 временных ряда на одном графике), показать предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> Добавила
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ## Вывод

# %% [markdown]
# В данной работе нашей задачей было построить модель предсказания количества заказов такси на следующий час.
#
# Сначала мы изучили данные и обнаружили общий тренд увеличения количества заказов за весь период 2018 года. Затем мы рассмотрели последний месяц и последнюю неделю: выяснилось, что на количество заказов влияет время дня и день недели.
#
# Далее мы подготовили признаки и проверили три модели, используя алгоритмы решающего дерева, линейной регрессии и LightLGBM. Последняя модель показала самую низкую среднеквадратичную ошибку (24.9), подходящую к требованиям проекта (ниже 48).
#
# Мы проверили лучшую модель на тестовой выборке - на ней среднеквадратичная ошибка оказалась выше (40.2), но она все еще лежит в пределах заявленных требований.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
